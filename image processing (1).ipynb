# %% [markdown]
# # Enhancing an image in Pillow using ImageFilter:

# %%
# 
from PIL import Image,ImageFilter  
#Read image
im = Image.open('img2.jpg')
#Display image  
im.show()
   
from PIL import ImageEnhance  
enh = ImageEnhance.Contrast(im)  
enh.enhance(1.9).show("30% more contrast")

# %% [markdown]
# # Segmentation of image

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.data import coins
from skimage.filters import threshold_otsu
from skimage.segmentation import clear_border
from skimage.morphology import label, closing, square
from skimage.measure import regionprops
from skimage.color import lab2rgb
# %matplotlib inline

# %%
def show(img, cmap=None):
    cmap = cmap or plt.cm.gray
    fig, ax = plt.subplots(1, 1, figsize=(8, 6))
    ax.imshow(img, cmap=cmap)
    ax.set_axis_off()
    plt.show()

# %%
img = coins()
show(img)

# %% [markdown]
# # segment the image is finding an intensity threshold separating the (bright) coins from the (dark) background. Otsu's method defines a simple algorithm to automatically find such a threshold.

# %%
threshold_otsu(img)
107
show(img > 107)

# %% [markdown]
# # perform the segmentation task itself with the label() function. This function detects the connected components in the image and attributes a unique label to every component. Here, we color code the labels in the binary image:

# %%
img_bin = clear_border(closing(img > 120, square(5)))
show(img_bin)
labels = label(img_bin)
show(labels, cmap=plt.cm.rainbow)

# %% [markdown]
# # gray scale image

# %%
gray_img = Image.open('img1.jpg').convert('L')
gray_img.show()
